# %% [markdown]
# ![brave_2iWkdwwrXz.webp](attachment:b3d70dc2-4e2a-49b4-b623-da90a9bf55e4.webp)

# %% [markdown]
# 평균(meu)을 중심으로 상위45%, 하위45%의 범위를 확보해야 한다. 이를 위해 z=(x-meu)/sigma라는 수식을 기반으로 x=meu+z*sigma로 치환하고 이 치환식을 기반으로 x에 대해서 크기가 1인
# 정규분포를 만들 수 있다. 이 정규분포를 기반으로 범위를 설정할 수 있다.
