# %% [markdown]
# ![image.png](attachment:ae8c43af-7fd0-491d-9e10-5696980132be.png)

# %%
import sympy as sp
import numpy as np

# Define symbols
t, phi = sp.symbols('t phi')

# Given expressions
expr_a1 = 3.2 * sp.cos(0.2*t - 0.3) + sp.sin(0.2*t + 0.4)
expr_a1
# Out:
# sin(0.2*t + 0.4) + 3.2*cos(0.2*t - 0.3)

# %%
y_a = sp.cos(0.2*t)*round(3.2*sp.cos(-0.3),1) - round(3.2* sp.sin(-0.3),1)*sp.sin(0.2*t) +sp.sin(0.2*t)*round(sp.cos(0.4),1) + sp.cos(0.2*t)*round(sp.sin(0.4),1)

print(f"4.2a)")
y_a
# Out:
# 4.2a)
# 2.0*sin(0.2*t) + 3.5*cos(0.2*t)

# %%
# Given expressions
expr_b1 = 12 * sp.sin(1*t - 0.4)
y_b = 12 * (sp.sin(t)*round(sp.cos(-0.4),2) + sp.cos(t)*round(sp.sin(-0.4),2))

print(f"4.2b)")
y_b
# y_b = expr_b
# print(f"4.2b) {y_b}")
# Out:
# 4.2b)
# 11.0*sin(t) - 4.7*cos(t)
