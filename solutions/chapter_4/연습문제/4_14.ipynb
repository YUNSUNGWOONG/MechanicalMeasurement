# %% [markdown]
# ![image.png](attachment:c0b43c0c-3a1d-4f9f-a889-5e9f97ab2084.png)

# %% [markdown]
# 온도 측정 회로는 8.3kHz 이하의 주파수에 완전히 반응한다. 이 주파수보다 높으면 신호를 약화시킨다. 이 회로는 알려지지 않은 주파수 스펙트럼을 가진 온도 신호를 측정하는데 사용될 예정이다. 주파수 구성요소에서 +/-1Hz의 정확도가 필요하다. 회로의 출력에 8.3kHz 이상의 주파수 구성요소가 없다면, 출력을 샘플림하기 위해 어떤 샘플링 주파수와 샘플수를 사용해야 하는가?
